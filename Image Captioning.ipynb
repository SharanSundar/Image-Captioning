# %%
from os import listdir
from pickle import dump
from keras.applications.vgg16 import VGG16
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing.text import Tokenizer
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical

# %%
# extract features from each photo in the directory
def extract_features(directory):
    # load the model
    model = VGG16()
    # re-structure the model
    model.layers.pop()
    model = Model(inputs=model.inputs, outputs=model.layers[-1].output)
    # summarize
    print(model.summary())
    # extract features from each photo
    features = dict()
    for name in listdir(directory):
        # load an image from file
        filename = directory + '/' + name
        image = load_img(filename, target_size=(224, 224))
        # convert the image pixels to a numpy array
        image = img_to_array(image)
        # reshape data for the model
        image = image.reshape((1, image.shape[0], image.shape[1], image.shape[2]))
        # prepare the image for the VGG model
        image = preprocess_input(image)
        # get features
        feature = model.predict(image, verbose=0)
        # get image id
        image_id = name.split('.')[0]
        # store feature
        features[image_id] = feature
        print('>%s' % name)
    return features

# %%
# # extract features from all images
# directory = 'Flicker8k_Dataset'
# features = extract_features(directory)
# print('Extracted Features: %d' % len(features))
# # save to file
# dump(features, open('features.pkl', 'wb'))
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 860s 2us/step
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# =================================================================
# Total params: 134,260,544
# Trainable params: 134,260,544
# Non-trainable params: 0
# _________________________________________________________________
# None
# >3148647065_2d6cd88cf6.jpg
# >2797438951_88a3ed7541.jpg
# >3248408149_41a8dd90d3.jpg
# >3427852996_d383abd819.jpg
# >3358621566_12bac2e9d2.jpg
# >3322200641_c2e51ff37b.jpg
# >3707077198_efd6aa808d.jpg
# >3372022051_132b8e6233.jpg
# >766346887_a9a9d0637a.jpg
# >238512430_30dc12b683.jpg
# >3580741947_cc64a83648.jpg
# >136886677_6026c622eb.jpg
# >2710563762_06d48329d7.jpg
# >2120383553_5825333a3f.jpg
# >3415287719_3c776f370e.jpg
# >3326588088_172d1b2584.jpg
# >864290968_eccb46d5ab.jpg
# >539493423_9d7d1b77fa.jpg
# >3258391809_38fc6211f7.jpg
# >3216926094_bc975e84b9.jpg
# >2424111022_4e332b8aee.jpg
# >2376878930_dd3e7cc544.jpg
# >2465497494_43d74df57c.jpg
# >327997381_55f90dc834.jpg
# >1167662968_e466f1e80a.jpg
# >3249125548_700d874380.jpg
# >1814086703_33390d5fc7.jpg
# >3163273640_8d3ef22eaf.jpg
# >661546153_9d30db6984.jpg
# >533979933_a95b03323b.jpg
# >1269470943_ba7fc49b4d.jpg
# >2528547068_7d37479b9b.jpg
# >470903027_489cc507de.jpg
# >58363930_0544844edd.jpg
# >1557451043_f5c91ff6f4.jpg
# >374176648_ba4b88c221.jpg
# >3483140026_e14f64fdf5.jpg
# >2792212974_23b1ef05fa.jpg
# >3522000960_47415c3890.jpg
# >2056930414_d2b0f1395a.jpg
# >2922981282_203f04bf9b.jpg
# >2364394224_c17b09e035.jpg
# >3398745929_8cd3bbb8a8.jpg
# >533483374_86c5d4c13e.jpg
# >3730457171_e66dde8c91.jpg
# >241347496_1a35fec8dc.jpg
# >457631171_12b1aee828.jpg
# >2578395598_6982734d46.jpg
# >35506150_cbdb630f4f.jpg
# >2728813605_cfc943e1ab.jpg
# >3329169877_175cb16845.jpg
# >3270273940_61ef506f05.jpg
# >2684489465_32ba1d0344.jpg
# >1456630952_dd4778a48f.jpg
# >2848571082_26454cb981.jpg
# >3290105461_7590f23371.jpg
# >2660008870_b672a4c76a.jpg
# >532396029_ce125bda3f.jpg
# >2282600972_c22d1e03c7.jpg
# >2797188545_aeb26c54c0.jpg
# >461505235_590102a5bf.jpg
# >2480820830_bdec1f5b76.jpg
# >2240539658_dea8db6e55.jpg
# >2741380826_cfe0ddf0a9.jpg
# >3621649810_cca783b777.jpg
# >2759211664_d21393b668.jpg
# >469969326_4b84073286.jpg
# >276699720_fe6718fd03.jpg
# >3229898555_16877f5180.jpg
# >2857372127_d86639002c.jpg
# >337793983_ac5b2e848e.jpg
# >1355703632_5683a4b6fb.jpg
# >3351357065_a6a9b3d485.jpg
# >1244306891_8e78ae1620.jpg
# >2039457436_fc30f5e1ce.jpg
# >1007320043_627395c3d8.jpg
# >2377460540_8cfb62463a.jpg
# >358559906_d5f3f584f4.jpg
# >3523950181_414978964e.jpg
# >1659358141_0433c9bf99.jpg
# >3668900592_a84b0c07db.jpg
# >2909955251_4b326a46a7.jpg
# >3191982761_88793192ed.jpg
# >3631671718_d712821757.jpg
# >751074141_feafc7b16c.jpg
# >1356796100_b265479721.jpg
# >2664103423_c539f61016.jpg
# >2938072630_d641b63e4d.jpg
# >2929006980_9f9f8f3d21.jpg
# >1731546544_9fbf14617b.jpg
# >1211015912_9f3ee3a995.jpg
# >300371487_daec5d11ab.jpg
# >2259203920_6b93b721ce.jpg
# >3662871327_b128d25f04.jpg
# >2470588201_955132a946.jpg
# >432248727_e7b623adbf.jpg
# >2737233999_34d60dc5c3.jpg
# >1410193619_13fff6c875.jpg
# >2717686269_80c4b5ac9e.jpg
# >2380740486_8cd5d4601a.jpg
# Extracted Features: 8091

# %% [markdown]
# # TEXT PREPROCESSING

# %%
import string

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# extract descriptions for images
def load_descriptions(doc):
    mapping = dict()
    # process lines
    for line in doc.split('\n'):
        # split line by white space
        tokens = line.split()
        if len(line) < 2:
            continue
        # take the first token as the image id, the rest as the description
        image_id, image_desc = tokens[0], tokens[1:]
        # remove filename from image id
        image_id = image_id.split('.')[0]
        # convert description tokens back to string
        image_desc = ' '.join(image_desc)
        # create the list if needed
        if image_id not in mapping:
            mapping[image_id] = list()
        # store description
        mapping[image_id].append(image_desc)
    return mapping

def clean_descriptions(descriptions):
    # prepare translation table for removing punctuation
    table = str.maketrans('', '', string.punctuation)
    for key, desc_list in descriptions.items():
        for i in range(len(desc_list)):
            desc = desc_list[i]
            # tokenize
            desc = desc.split()
            # convert to lower case
            desc = [word.lower() for word in desc]
            # remove punctuation from each token
            desc = [w.translate(table) for w in desc]
            # remove hanging 's' and 'a'
            desc = [word for word in desc if len(word)>1]
            # remove tokens with numbers in them
            desc = [word for word in desc if word.isalpha()]
            # store as string
            desc_list[i] =  ' '.join(desc)

# convert the loaded descriptions into a vocabulary of words
def to_vocabulary(descriptions):
    # build a list of all description strings
    all_desc = set()
    for key in descriptions.keys():
        [all_desc.update(d.split()) for d in descriptions[key]]
    return all_desc

# save descriptions to file, one per line
def save_descriptions(descriptions, filename):
    lines = list()
    for key, desc_list in descriptions.items():
        for desc in desc_list:
            lines.append(key + ' ' + desc)
    data = '\n'.join(lines)
    file = open(filename, 'w')
    file.write(data)
    file.close()

filename = 'Flickr8k.token.txt'
# load descriptions
doc = load_doc(filename)
# parse descriptions
descriptions = load_descriptions(doc)
print('Loaded: %d ' % len(descriptions))
# clean descriptions
clean_descriptions(descriptions)
# summarize vocabulary
vocabulary = to_vocabulary(descriptions)
print('Vocabulary Size: %d' % len(vocabulary))
# save to file
save_descriptions(descriptions, 'descriptions.txt')
# Out:
# Loaded: 8092
# Vocabulary Size: 8763

# %%
from pickle import load

# load doc into memory
def load_doc(filename):
    # open the file as read only
    file = open(filename, 'r')
    # read all text
    text = file.read()
    # close the file
    file.close()
    return text

# load a pre-defined list of photo identifiers
def load_set(filename):
    doc = load_doc(filename)
    dataset = list()
    # process line by line
    for line in doc.split('\n'):
        # skip empty lines
        if len(line) < 1:
            continue
        # get the image identifier
        identifier = line.split('.')[0]
        dataset.append(identifier)
    return set(dataset)

# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
    # load document
    doc = load_doc(filename)
    descriptions = dict()
    for line in doc.split('\n'):
        # split line by white space
        tokens = line.split()
        # split id from description
        image_id, image_desc = tokens[0], tokens[1:]
        # skip images not in the set
        if image_id in dataset:
            # create list
            if image_id not in descriptions:
                descriptions[image_id] = list()
            # wrap description in tokens
            desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
            # store
            descriptions[image_id].append(desc)
    return descriptions

# load photo features
def load_photo_features(filename, dataset):
    # load all features
    all_features = load(open(filename, 'rb'))
    # filter features
    features = {k: all_features[k] for k in dataset}
    return features

# load training dataset (6K)
filename = 'Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# photo features
train_features = load_photo_features('features.pkl', train)
print('Photos: train=%d' % len(train_features))
# Out:
# Dataset: 6000
# Descriptions: train=6000
# Photos: train=6000

# %%
# for keys,values in train_features.items():
#     print(keys)
#     print(values)

# %%
train_descriptions
# Out:
# {'1445123245_c7b9db0e0c': ['startseq black and tan dog plays with centipede toy endseq',
#   'startseq dog tags nap on rug near his favorite toy plush centipede endseq',
#   'startseq short long haired dog plays with multicolored stuffed toy centipede endseq',
#   'startseq small brown and black dog plays with colorful caterpillar toy on tan burbur carpet endseq',
#   'startseq yorkshire terrier plays with multicolor centipede toy endseq'],
#  '1236951314_0308dc4138': ['startseq boy in wetsuit jumps into pool with bald man endseq',
#   'startseq boy with goggles jumping into pool containing man endseq',
#   'startseq child is jumping into pool while man is watching the child endseq',
#   'startseq swimming person is watching child jump into pool with blue water endseq',
#   'startseq young boy jumps in swimming pool towards bald man in the water endseq'],
#  '3533775651_9d7e93dacf': ['startseq person in red is opening red car door in parking area endseq',
#   'startseq woman gets out of red car endseq',
#   'startseq two people embrace outside of red car at night in brightlylit city endseq',
#   'startseq two people standing next to red car are hugging in traffic with brightly lit city scene behind them endseq',
#   'startseq two people stand outside of red car in the city and hug endseq'],
#  '2561341745_2d77d3ff7d': ['startseq thin girl in black smokes cigarette endseq',
#   'startseq woman dressed in black and white smokes cigarette in grassy area endseq',
#   'startseq woman wearing plaid skirt stands holding cigarette endseq',
#   'startseq the woman in the black coat is standing with cigarette in her hand endseq',
#   'startseq women wearing black standing and smoking endseq'],
#  '2393971707_bce01ae754': ['startseq people in red and pink walking down large steps endseq',
#   'startseq people walk down steps endseq',
#   'startseq two people descending set of gray steps endseq',
#   'startseq two people walking down some stairs endseq',
#   'startseq two women walk down some stairs with intricate designs on the railings endseq'],
#  '795081510_53fd17d101': ['startseq couple hold each other standing on ferry looking out at ferry endseq',
#   'startseq couple standing on the deck of boat watching the water endseq',
#   'startseq man embraces woman as they look over the railing out over the water at ship endseq',
#   'startseq couple overlooking metal rail with water and boat int he background endseq',
#   'startseq the couple is together looking at the large ship in the ocean endseq'],
#  '3639617775_149001232a': ['startseq bridal party poses for picture endseq',
#   'startseq wedding party stands in the church getting their picture taken endseq',
#   'startseq wedding photo of ten people with big smiles wearing black and white outfits endseq',
#   'startseq the bridal party poses with the bride and groom all wearing black except for the bride endseq',
#   'startseq the bride in the white dress is surrounded by the groomsmen and bridesmaids all in black endseq'],
#  '3520321387_710ab74cda': ['startseq lady is smiling with her blonde haired son endseq',
#   'startseq woman and young boy endseq',
#   'startseq woman and child laugh endseq',
#   'startseq woman and child smile for picture endseq',
#   'startseq mother and son grin for the camera endseq'],
#  '2709683703_5385ea9ef4': ['startseq man is squirting water into white dog mouth with squirt gun endseq',
#   'startseq man spraying super soaker into the mouth of dog endseq',
#   'startseq young man squirts water from water gun into dog mouth endseq',
#   'startseq man squirts water gun in dogs mouth endseq',
#   'startseq the young man with the water gun is shooting water into the white dogs mouth endseq'],
#  '1370615506_2b96105ca3': ['startseq wine shop with an open sign in the window and two people out front endseq',
#   'startseq the wine shop endseq',
#   'startseq the wine shop on twenty fourth building lit up in the dark two people in front endseq',
#   'startseq two people are standing outside of wine shop endseq',
#   'startseq two people stand outside wine shop endseq'],
#  '2363419943_717e6b119d': ['startseq lady and her little girl are holding hands and walking up the sidewalk endseq',
#   'startseq mother and child run hand in hand through chinatown in an american city endseq',
#   'startseq woman and child both wearing red outfits walking up street endseq',
#   'startseq child in red holding the hand of person in red coat walking on sidewalk under awnings endseq',
#   'startseq woman and little girl wearing red in asian area endseq'],
#  '3341077091_7ca0833373': ['startseq boy is airborne on his skateboard above set of rails in an industrial setting endseq',
#   'startseq boy with skateboard if jumping in the air along some railway tracks endseq',
#   'startseq man doing skateboard trick over railroad track endseq',
#   'startseq skateboarder does kickflip along the train tracks endseq',
#   'startseq skateboarder doing jump on train tracks endseq'],
#  '2687539673_d54a8dc613': ['startseq girl and young boy are jumping on trampoline in suburban yard endseq',
#   'startseq girl is jumping on trampoline with her arms in the air while boy in blue shirt is bouncing on his stomach endseq',
#   'startseq teenager girl jumps high on trampoline and toddler falls on his stomach endseq',
#   'startseq toddler and teenage girl jumping on trampoline endseq',
#   'startseq two children jump on trampoline endseq'],
#  '3552796830_2dd2aa9c2c': ['startseq two men in camouflage pants are running past parking lot endseq',
#   'startseq two men in camouflage pants are running past parking lot endseq',
#   'startseq two men run through parking lot wearing camouflage pants endseq',
#   'startseq two men wearing army pants are running next to fence endseq',
#   'startseq two soldiers are running down track endseq'],
#  '516998046_1175674fcd': ['startseq black dog splashes through the water endseq',
#   'startseq brown and tan dog is running through shallow water endseq',
#   'startseq dog is running in the ocean beside the beach endseq',
#   'startseq dog running through water endseq',
#   'startseq dog splashes running across water endseq'],
#  '3543600125_223747ef4c': ['startseq lady laughs as she and man drink coffee endseq',
#   'startseq man and girl are sitting down and have drink endseq',
#   'startseq man and woman are drinking from ceramic cups in front of brick wall endseq',
#   'startseq woman in black is sitting next to man wearing glasses in coffee shop endseq',
#   'startseq people sitting in building having drinks endseq'],
#  '2501968935_02f2cd8079': ['startseq man dressed in purple shirt and red bandanna smiles at the people watching him endseq',
#   'startseq man on the street wearing leather chaps and chainmail codpiece endseq',
#   'startseq man wearing purple shirt and black leather chaps poses for the camera endseq',
#   'startseq man dressed in leather chaps and purple shirt stands in front of onlookers endseq',
#   'startseq there is man in purple shirt leather chaps and red bandanna standing near other men endseq'],
#  '1354318519_2f9baed754': ['startseq baby is laughing endseq',
#   'startseq baby laughs at his reflection in mirror endseq',
#   'startseq blonde haired toddler in burgundy hoodie smiling endseq',
#   'startseq boy in red hooded top is smiling whilst looking away from his reflection endseq',
#   'startseq child in front of his own reflection turning towards the camera and smiling endseq'],
#  '2199200615_85e4c2a602': ['startseq dog running on green grass with its mouth open and tongue hanging out endseq',
#   'startseq dog runs across the grass endseq',
#   'startseq dog runs across the grassy field endseq',
#   'startseq white black and brown dog runs in field endseq',
#   'startseq white dog is running with its mouth open across the grass endseq'],
#  '405331006_4e94e07698': ['startseq man in blue cowboy hat is riding white horse endseq',
#   'startseq man in blue is riding horse on dirt road endseq',
#   'startseq man wearing blue hat and shirt is riding white horse endseq',
#   'startseq person in blue cowboy hat rides horse down dirt trail endseq',
#   'startseq the person in the blue shirt and blue hat is riding white horse endseq'],
#  '444881000_bba92e585c': ['startseq group of college students walk in nice weather endseq',
#   'startseq group of people walk in the park while some talk on phones endseq',
#   'startseq group of students are walking through the campus endseq',
#   'startseq group of young people walking with two talking on cellphones endseq',
#   'startseq several young people walking casually around endseq'],
#  '2469351714_d72becd21e': ['startseq child is leaping into the air from sand dune near the beach endseq',
#   'startseq girl jumping high off of the sand endseq',
#   'startseq girl jumping on sand dune at the ocean endseq',
#   'startseq young girl jumping in the sand on the beach endseq',
#   'startseq the little girl jumps up into the air with the sand beneath her endseq'],
#  '2350400382_ced2b6c91e': ['startseq black dog caught in midjump catching toy in his mouth endseq',
#   'startseq black dog flies through the air while holding an object in its mouth endseq',
#   'startseq black dog jumps in the air to catch toy endseq',
#   'startseq black dog running with black and white toy in its mouth endseq',
#   'startseq dog is in field on very windy day with something in its mouth endseq'],
#  '3172283002_3c0fc624de': ['startseq four people are posing outside endseq',
#   'startseq four people posing for picture endseq',
#   'startseq four people two women in the front and man and woman in the back pose at night endseq',
#   'startseq one man and three women pose for the camera endseq',
#   'startseq three women and one man are posing for picture endseq'],
#  '2555521861_fc36fd3ab0': ['startseq girl holds onto rope above the water endseq',
#   'startseq girl wearing harness is lifted out of the water endseq',
#   'startseq person attached to harness is being dragged through the water endseq',
#   'startseq person in harness is hanging above water making spray with their feet endseq',
#   'startseq person on pulley is dragged across water endseq'],
#  '3141613533_595723208d': ['startseq two boys standing in an empty corn field in the winter endseq',
#   'startseq two people stand on harvested field in cold weather endseq',
#   'startseq two young boys standing in corn field after the harvest endseq',
#   'startseq two young boys wearing jackets frolic in large field endseq',
#   'startseq two young people brave the cold endseq'],
#  '2483993827_243894a4f9': ['startseq three greyhounds are racing on track at night endseq',
#   'startseq three lean numbered greyhounds race along track endseq',
#   'startseq two greyhounds racing at night endseq',
#   'startseq two horses are right alongside each other in the race endseq',
#   'startseq white black and brown greyhounds racing in numbered shirts endseq'],
#  '2090327868_9f99e2740d': ['startseq woman little boy and tiny baby are standing in front of cow statue endseq',
#   'startseq woman and two small children posing in front of large cow statue endseq',
#   'startseq woman gives baby to small child to hold as they stand in front of cow statue endseq',
#   'startseq woman stands with two children near decorated bull statue endseq',
#   'startseq the woman and children are standing next to statue of cow endseq'],
#  '2052202553_373dad145b': ['startseq brown dog wades into lake to retrieve stick endseq',
#   'startseq dog carries very big stick through the water endseq',
#   'startseq dog holds stick in its mouth in the water endseq',
#   'startseq dog is running through creek with stick in its mouth endseq',
#   'startseq reddish brown dog walking in water carrying stick in his mouth endseq'],
#  '485357535_b45ba5b6da': ['startseq boy in black and white shirt holds red skateboard as he stands over the hollywood stars endseq',
#   'startseq skateboarder examines the hollywood walk of fame endseq',
#   'startseq teenage boy wearing striped shirt walks on street paved with stars carrying skateboard endseq',
#   'startseq man walking with red skateboard endseq',
#   'startseq person wearing black and white striped shirt holding red skateboard standing on sidewalk with stars endseq'],
#  '2570365455_41cc9a7d2b': ['startseq two boys show off their stained blue tongues endseq',
#   'startseq two boys with wearing baseball caps are sticking out green stained tongues endseq',
#   'startseq two kids are sticking their blue and green colored tongues out endseq',
#   'startseq two young boys wearing collared shirts and baseball caps have their bluetinted tongues stuck out endseq',
#   'startseq two young boys wearing hats and sticking their colored tongues out endseq'],
#  '2546959333_23b957988f': ['startseq dog nipping at the feet of cow endseq',
#   'startseq dog pounces on the grass endseq',
#   'startseq the dog is running after the bull endseq',
#   'startseq the large brown dog is playing in the grass with brown cow endseq',
#   'startseq two dogs outside on green grass endseq'],
#  '3323498985_fd9d2803fd': ['startseq man falling over in an ocean wave endseq',
#   'startseq man in swimming trunks plays in the ocean waves endseq',
#   'startseq man is falling into waves endseq',
#   'startseq surfer falling of his board into wave endseq',
#   'startseq young man in swim shorts is jumping over wave in the ocean endseq'],
#  '3654338683_13b2f95a9a': ['startseq dog runs through grassy field of yellow flowers endseq',
#   'startseq dog runs through the long grass endseq',
#   'startseq golden retriever runs through field of yellow flowers endseq',
#   'startseq white dog runs through field of yellow flowers endseq',
#   'startseq white dog running through field of yellow flowers endseq'],
#  '766061382_6c7ff514c4': ['startseq bare chested smiling child plays in water endseq',
#   'startseq child with shoulderlength brown hair is playing in water outdoors endseq',
#   'startseq topless boy with long hair who is drenched in water is flexing his muscles whilst smiling endseq',
#   'startseq wet smiling child without shirt poses with arms raised endseq',
#   'startseq young boy with long hair plays in the water endseq'],
#  '3330680118_4e541889c1': ['startseq boy bundled up siting on one person sleigh in the snow endseq',
#   'startseq child in blue sitting on sled in the snow endseq',
#   'startseq kid sits on skiing device in the snow endseq',
#   'startseq small child is riding on toboggan endseq',
#   'startseq there is child on sled type machine in the snow endseq'],
#  '222369445_5b6af347dd': ['startseq man is carrying surfboard along stone wall that leads to the ocean endseq',
#   'startseq man in green swim trunks carrying surfboard along rock wall to the ocean endseq',
#   'startseq surfers walking along seawall as the ocean churns around them endseq',
#   'startseq two surfers carry their boards to the end of walkway to join the others in the water endseq',
#   'startseq two surfers walk along rock wall to reach the waves endseq'],
#  '2876494009_9f96d7eaf2': ['startseq rollerblader is in midair on ramp endseq',
#   'startseq rollerblader in the air above ramp endseq',
#   'startseq skateboarder in black on ramps in midair pose endseq',
#   'startseq skateboarder jumping from one quarterpipe to another endseq',
#   'startseq three young boys are skateboarding on ramp endseq'],
#  '485054073_fef8b80b4b': ['startseq frisbee casts shadow on the dog endseq',
#   'startseq white dog is attempting to catch green and pink object endseq',
#   'startseq white dog with long hair jumps to catch red and green toy endseq',
#   'startseq white furry dog jumping to catch frisbee endseq',
#   'startseq the dog is trying to catch frisbee endseq'],
#  '3182405529_7692256746': ['startseq bearded man is riding bicycle on the beach endseq',
#   'startseq man with grey beard rides his bike on the beach of the ocean endseq',
#   'startseq an older man with long grey hair and long grey beard bike riding on the shore endseq',
#   'startseq whitebearded man rides bicycle on the beach endseq',
#   'startseq gentleman with long grey hair and beard riding bicycle on the beach endseq'],
#  '3498417123_3eae6bbde6': ['startseq group of men are playing ball together endseq',
#   'startseq group of men play rugby endseq',
#   'startseq rugby match in progress is shown with the referee watching endseq',
#   'startseq seven men are in action playing rugby endseq',
#   'startseq while the green team gets ready to tackle the red team has the ball endseq'],
#  '396179143_e1511336e1': ['startseq golden retriever on leash moves through snow endseq',
#   'startseq large golden retriever on leash standing in the snow endseq',
#   'startseq tan dog on leash walks in the snow endseq',
#   'startseq tan dog on lead standing on surface covered with white snow endseq',
#   'startseq the small dog on the leash is walking through the snow endseq'],
#  '539493431_744eb1abaa': ['startseq man is playing with fire baton in the day light endseq',
#   'startseq man juggling fire endseq',
#   'startseq man stands near playground endseq',
#   'startseq man throws flames outside endseq',
#   'startseq the guy is holding black stick in front of playground endseq'],
#  '3018304737_0a46fc5f1d': ['startseq lone surfboarder surfing wave riding white surfboard endseq',
#   'startseq man catches huge wave on his surfboard endseq',
#   'startseq surfboarder going down wave endseq',
#   'startseq surfer makes turn on wave endseq',
#   'startseq the surfer is riding wave endseq'],
#  '2089350172_dc2cf9fcf6': ['startseq three black dogs are swimming through some murky brown water one with yellow object in its mouth endseq',
#   'startseq three black dogs swimming in dirty water endseq',
#   'startseq three dark dogs swimming and one of them has ball endseq',
#   'startseq three dogs are up to their necks in water endseq',
#   'startseq three dogs swim in the water endseq'],
#  '337647771_3b819feaba': ['startseq dog has its head inside red and green gift bag endseq',
#   'startseq pet playfully investigates the contents of gift bag endseq',
#   'startseq little brown dog sticking head in coloful bag filled with cloth endseq',
#   'startseq the dog has his face in the bag of christmas presents endseq',
#   'startseq the redbrown dog digs his nose to investigate holiday gift bag endseq'],
#  '2976350388_3984e3193d': ['startseq bicycler jumping over barrier with his bike endseq',
#   'startseq cyclist carries his bicycle while jumping over hurdle endseq',
#   'startseq man doing tricks with his bicycle endseq',
#   'startseq man jumps across an obstacle carrying his bike endseq',
#   'startseq the man is jumping through the air while holding bicycle endseq'],
#  '3556037801_3992ce6826': ['startseq man is fixing the wheel of bicycle inside cycling store endseq',
#   'startseq man works in bike shop endseq',
#   'startseq woman in bicycle store where two men are working on bike endseq',
#   'startseq woman in red shirt is examining one of many bicycles while man in blue shirt is adjusting wheel endseq',
#   'startseq people shopping in bike shop endseq'],
#  '3062273350_fd66106f21': ['startseq men wearing hats and coats are walking together endseq',
#   'startseq group of old men walking down the street endseq',
#   'startseq group of seven men walking and standing on concrete surface endseq',
#   'startseq group of walking men endseq',
#   'startseq seven older gentlemen walking together in group outside endseq'],
#  '3211437611_bd4af3730b': ['startseq bridal party surrounding bride sitting on couch endseq',
#   'startseq bride is sitting on tan couch endseq',
#   'startseq bride seated on sofa with her bridal party and family surrounding her endseq',
#   'startseq old picture of wedding endseq',
#   'startseq the brides side of wedding party endseq'],
#  '207275121_ee4dfa0bf2': ['startseq brown dog running in yard endseq',
#   'startseq dog runs on the grass in yard gazebo in the background endseq',
#   'startseq dog trotting through someone yard endseq',
#   'startseq large brown dog is running through grassy backyard endseq',
#   'startseq large brown dog runs through large grassy area endseq'],
#  '3004359992_f6b3617706': ['startseq group of girls in cheerleader clothing tosses another girl into the air with an athletic field in the background endseq',
#   'startseq group of young women one up in the air endseq',
#   'startseq cheerleaders throw girl in air endseq',
#   'startseq five girls cheerleading endseq',
#   'startseq the cheerleaders toss their fellow member in the air endseq'],
#  '2396100671_3a9d67f03d': ['startseq boy in costume is sitting on bike endseq',
#   'startseq child in dragon costume on bike endseq',
#   'startseq child wearing costume rides bike in winter endseq',
#   'startseq little boy on bike wearing dragon costume endseq',
#   'startseq young boy sits on his bike wearing dragon costume endseq'],
#  '2807177340_bc85291df5': ['startseq boy playing on playground endseq',
#   'startseq boys plays at the playground endseq',
#   'startseq child in jeans and tshirt hangs from monkeybars at playground endseq',
#   'startseq africanamerican boy is playing on playground endseq',
#   'startseq smiling boy hangs onto zipline structure at playground endseq'],
#  '1055623002_8195a43714': ['startseq group of four children wearing pajamas have pillow fight endseq',
#   'startseq group of kids have pillowfight endseq',
#   'startseq group of young children playing pillow fight on bed endseq',
#   'startseq children having pillow fight endseq',
#   'startseq four children are having pillow fight endseq'],
#  '3273625566_2454f1556b': ['startseq black greyhound in white and green coming up on the rear of white greyhound in yellow and black in race endseq',
#   'startseq greyhound running on track endseq',
#   'startseq racing dog with yellow number vest endseq',
#   'startseq the greyhound is running in race endseq',
#   'startseq the racing dog has muzzle and is wearing striped jersey endseq'],
#  '1659358133_95cd1027bd': ['startseq brown dog sniffs tree stump endseq',
#   'startseq dog sniffs newly cut tree trunk endseq',
#   'startseq dog sniffs tree stump endseq',
#   'startseq dog sniffing recently cut tree stump endseq',
#   'startseq the dog is standing outside on tree stump endseq'],
#  '2644326817_8f45080b87': ['startseq black and white dog with red frisbee standing on sandy beach endseq',
#   'startseq dog drops red disc on beach endseq',
#   'startseq dog with red frisbee flying in the air endseq',
#   'startseq dog catching red frisbee endseq',
#   'startseq the black dog is dropping red disc on beach endseq'],
#  '3533470072_87a5b595ba': ['startseq two girls giving the peace sign endseq',
#   'startseq two girls waving two fingers endseq',
#   'startseq two young girls one blonde one brunette are puckering there lips and showing peace sign with there fingers endseq',
#   'startseq two young women in identical blue dresses giving the peace sign in an auditorium endseq',
#   'startseq twp young ladies give the piece sign with their fingers to the camera endseq'],
#  '571507143_be346225b7': ['startseq group of kids plays in the spray of water from fountain endseq',
#   'startseq children are being splashed with water endseq',
#   'startseq children are playing outside in fountain endseq',
#   'startseq five children are being sprayed by water fountain endseq',
#   'startseq four children are playing in water fountain endseq'],
#  '544257613_d9a1fea3f7': ['startseq blond man with big blue eyes is smiling endseq',
#   'startseq man in green scarf is bearing his teeth endseq',
#   'startseq man making funny face towards the camera using wide eyes and large smile endseq',
#   'startseq man with red hair grins endseq',
#   'startseq strawberry haired guy flashes his blue eyes and big smile at the camera endseq'],
#  '3330019493_fd36fbc2ea': ['startseq distorted picture of guy on motorbike in forest endseq',
#   'startseq guy on bike in the forest endseq',
#   'startseq man on motorcycle in the woods wearing black helmet endseq',
#   'startseq mountain biker in the forest endseq',
#   'startseq mountain biker riding through forest endseq'],
#  '2707969386_94dde00ce4': ['startseq little grey dog is jumping over fence endseq',
#   'startseq little grey dog jumps over small hurdle endseq',
#   'startseq little grey dog jumps over bar at an agility test endseq',
#   'startseq small dog jumping an obstacle in grassy field endseq',
#   'startseq small dog jumping over an obstacle endseq'],
#  '3280173193_98c2d6a223': ['startseq man two women and two dogs on beach with buildings in the background endseq',
#   'startseq three people and white dog are sitting in the sand on beach endseq',
#   'startseq three people on city beach with two little dogs endseq',
#   'startseq two girls wrestle in the sand at the beach as tan dog walks by endseq',
#   'startseq two women wrestle at the beach next to city endseq'],
#  '1423997242_ea2189ec5e': ['startseq hiker resting in field endseq',
#   'startseq man enjoys peaceful solitary moment while camping endseq',
#   'startseq man relaxes with his backpack endseq',
#   'startseq man sits on field near backpack endseq',
#   'startseq man with backpack takes rest in the tall grass endseq'],
#  '491964988_414b556228': ['startseq little girl runs down path in japanese garden endseq',
#   'startseq little girl skips down path near an idyllic country pond endseq',
#   'startseq young girl hops on the path to avoid the puddles located near lake endseq',
#   'startseq young girl is jumping on gravel road near pond endseq',
#   'startseq the girl runs near pond endseq'],
#  '374567836_3ae12ecffb': ['startseq brown dog with green ball sit in the snow endseq',
#   'startseq brown fluffy dog lays in the snow with its green ball endseq',
#   'startseq dog sits in the snow with tennis ball endseq',
#   'startseq little dog sits in the snow next to his green toy endseq',
#   'startseq dog in snow with ice on fur and yellow ball endseq'],
#  '225909073_25c3c33a29': ['startseq black and brown dog is running out of the surf endseq',
#   'startseq wet dog runs through the surf at beach endseq',
#   'startseq wet german shepherd dog is running out of the ocean with ball in its mouth endseq',
#   'startseq german shepherd running in ocean surf endseq',
#   'startseq the german shepherd is walking in the body of water endseq'],
#  '3571039224_b34fa2f94c': ['startseq black dog in shallow water endseq',
#   'startseq black dog on leash with red collar has its face in the water endseq',
#   'startseq black dog sticking its nose into the water endseq',
#   'startseq black dog with red collar sticks his head in the water endseq',
#   'startseq dog with black fur has put its head underwater endseq'],
#  '3585117340_73e96b6173': ['startseq pile of dogs sleep on blue dog bed endseq',
#   'startseq four puppies sleeping on blue blanket endseq',
#   'startseq four spotted puppies take nap endseq',
#   'startseq four white and brown puppies are sleeping together on blue blanket endseq',
#   'startseq four young puppies snuggling together in the middle of blanket endseq'],
#  '417966898_a04f9b5349': ['startseq two girls hanging upside down on park structure endseq',
#   'startseq two girls hang upside down at park endseq',
#   'startseq two girls play on jungle gym endseq',
#   'startseq two little girls are hanging upsidedown on climbing frame endseq',
#   'startseq two young girls playing outside on the playground endseq'],
#  '2125626631_a4b63af97e': ['startseq dog catching frisbee endseq',
#   'startseq dog makes faithful leap to catch green and black frisbee in his mouth endseq',
#   'startseq leaping dog catches green and black frisbee endseq',
#   'startseq white dog is airborne whilst catching green toy endseq',
#   'startseq small dog jumps sideways to catch soft disc endseq'],
#  '3626998066_3ae11ee278': ['startseq brown dog chases another brown dog who has green ball endseq',
#   'startseq two black dogs are running in the grass one has green ball in his mouth endseq',
#   'startseq two brown dogs are playing with green toy on grass endseq',
#   'startseq two brown dogs run through field endseq',
#   'startseq two brown dogs run together endseq'],
#  '1679565118_d36f0d6d52': ['startseq black dog catches tennis ball in his mouth while white dog watches endseq',
#   'startseq black dog jumps to catch ball in his mouth near rock wall endseq',
#   'startseq black dog jumping in the air with white dog standing on grass behind near pile of rocks endseq',
#   'startseq black dog jumping to catch tennis ball endseq',
#   'startseq the black dog is catching ball while the white one watches endseq'],
#  '104136873_5b5d41be75': ['startseq people sit on the mountainside and check out the view endseq',
#   'startseq three people are on hilltop overlooking green valley endseq',
#   'startseq three people hang out on top of big hill endseq',
#   'startseq three people overlook green valley endseq',
#   'startseq three people rest on ledge above the moutains endseq'],
#  '1260816604_570fc35836': ['startseq person drives in red car endseq',
#   'startseq person in red car with bridge in the background endseq',
#   'startseq person waits inside red compact car endseq',
#   'startseq red car driving over bridge endseq',
#   'startseq the lady in the red car is crossing the bridge endseq'],
#  '3423802527_94bd2b23b0': ['startseq bunch of girls in cheerleader outfits endseq',
#   'startseq large group of cheerleaders walking in parade endseq',
#   'startseq cheerleaders perform endseq',
#   'startseq many cheerleaders wearing black walk down the street endseq',
#   'startseq parade of cheerleaders wearing black pink and white uniforms endseq'],
#  '3396036947_0af6c3aab7': ['startseq boy on swing endseq',
#   'startseq little boy is swinging on swing beside some trees and river endseq',
#   'startseq toddler swings back very high endseq',
#   'startseq young boy is riding swing high in the air endseq',
#   'startseq small child swinging on swing with trees in the background endseq'],
#  '2591486448_48d5438343': ['startseq brown dog is wanting food from plate held by person endseq',
#   'startseq brown dog looking at plate with food someone hand taking from it endseq',
#   'startseq brown dog resting his head on the lap of person who is eating some food endseq',
#   'startseq dog head is in the lap of person eating off small plate endseq',
#   'startseq the brown dog with the red collar is staring at the plate of food endseq'],
#  '42637986_135a9786a6': ['startseq silhouette of two people sitting on dock at sunset endseq',
#   'startseq two people are sitting on wooden dock on lake at sunset endseq',
#   'startseq two people sit on dock with sunset in the background endseq',
#   'startseq two people sit on the pier together and look out at the ocean endseq',
#   'startseq two people sitting on dock under lamp post with clouds in the sky beyond them endseq'],
#  '3636543173_15f56515e5': ['startseq man has his hands up while standing next to another man with drink endseq',
#   'startseq young man stands in crowd beside another young man holding beverage can endseq',
#   'startseq the man wearing the brown jacket is holding cigarette and the man behind him is holding can of beer endseq',
#   'startseq two young men are at party endseq',
#   'startseq two young men are posing for the camera endseq'],
#  '1474474514_b3eb492722': ['startseq child smiling in park endseq',
#   'startseq little boy wearing blue shirt is playing around large tires endseq',
#   'startseq small child in blue shirt is standing in front of group of tires endseq',
#   'startseq young boy wearing mickey mouse clothes in jungle gym endseq',
#   'startseq the little boy is playing by tires endseq'],
#  '2892395757_0a1b0eedd2': ['startseq bicycler is riding bike at racing event endseq',
#   'startseq cyclist wearing black helmet is riding by some black vans endseq',
#   'startseq person on bicycle goes down the street endseq',
#   'startseq funky bicycle being raced endseq',
#   'startseq man wearing helmet and racing gear on bicycle endseq'],
#  '241109594_3cb90fe2a3': ['startseq black and white dog is biting onto stick in the water endseq',
#   'startseq black and white dog swimming with stick in its mouth endseq',
#   'startseq dog swimming in the water with stick in its mouth endseq',
#   'startseq dog swims retrieving stick endseq',
#   'startseq this black and white dog is retrieving stick from the water endseq'],
#  '2938316391_97382d14aa': ['startseq girl in hoodie and bikini bottom is standing on the beach with camera endseq',
#   'startseq woman in striped hoodie holds camera on beach endseq',
#   'startseq woman stands on beach with camera endseq',
#   'startseq woman takes pictures at the beach endseq',
#   'startseq woman with hooded sweatshirt and bikini bottoms holding camera at beach side endseq'],
#  '3214579977_fa9fb006a6': ['startseq black dog jumps in the snow endseq',
#   'startseq black dog jumps to catch frisbee in the snow endseq',
#   'startseq black dog in snow leaps for red object at upper edge of frame endseq',
#   'startseq one black dog is jumping off the snow filled ground endseq',
#   'startseq the black dog jumps out of the snow to catch an object endseq'],
#  '2661294969_1388b4738c': ['startseq float representing the times of hanging is shown in the back of truck endseq',
#   'startseq man in judge costume stand on red truck and hangs dummy endseq',
#   'startseq man dressed as judge pretending to hang another man on top of truck endseq',
#   'startseq three people in costumes stand on the back of pickup truck endseq',
#   'startseq three people stand on the back of truck endseq'],
#  '661546153_9d30db6984': ['startseq baby is in an activity chair in child playroom endseq',
#   'startseq baby is in an bouncy seat with toys surrounding him endseq',
#   'startseq baby playing in toy endseq',
#   'startseq smiling baby is sitting in white baby bouncer surrounded by toys endseq',
#   'startseq smilling and laughing baby in walker with fire engine airplane mobile and other toys on the floor endseq'],
#  '1176580356_9810d877bf': ['startseq big dog catches ball on his nose endseq',
#   'startseq brown and black dog is jumping to catch red ball endseq',
#   'startseq brown and black dog jumps for red ball endseq',
#   'startseq dog jumps to get orange ball on his head endseq',
#   'startseq the brown and black dog is jumping up to catch red ball endseq'],
#  '1819261140_6c022f4b1d': ['startseq costumed diner sits in restaurant wearing black outfit that covers their face endseq',
#   'startseq costumed figure leans into the dinner table endseq',
#   'startseq man dressed in dark costume sitting at restaurant table endseq',
#   'startseq man sitting at table with scary mask covering his face endseq',
#   'startseq person at table dressed in black costume endseq'],
#  '3401333624_4b6af8c1d7': ['startseq group of people stand in the snow in mountain endseq',
#   'startseq person is jumping over house on skis endseq',
#   'startseq snowboarder jumps over shed endseq',
#   'startseq people watch as person skis down mountain endseq',
#   'startseq skiiers on snowy mountain endseq'],
#  '3035118753_69287079dc': ['startseq blonde boy and girl in pajamas with makeup endseq',
#   'startseq girl with her arm around boy covering his face endseq',
#   'startseq little girls puts her arm around little boy endseq',
#   'startseq young girl hugs little boy endseq',
#   'startseq the little boy sitting next to the girl is covering his face with his hand endseq'],
#  '2362377137_9528692825': ['startseq busy city street with neon lights lots of people and traffic endseq',
#   'startseq crowd scene in downtown area endseq',
#   'startseq group of people on the sidewalk of city street endseq',
#   'startseq an opposite side streetshot of applebee and dave and buster restaurants endseq',
#   'startseq people are gathered on city street with police vehicles arriving endseq'],
#  '3110614694_fecc23ca65': ['startseq dog is running on snow with snowball it its mouth endseq',
#   'startseq dog running across the snow with snowball in its mouth endseq',
#   'startseq reddish brown dog runs across the snow with snowball in its mouth endseq',
#   'startseq the beautiful reddish dog lopes around the flat snowy street with snowball in its mouth endseq',
#   'startseq the brown dog runs on the snow with white ball in his mouth endseq'],
#  '2085400856_ae09df33a7': ['startseq dog in the snow endseq',
#   'startseq dog laying in the snow endseq',
#   'startseq dog lays on the snow endseq',
#   'startseq golden dog plays in the snow endseq',
#   'startseq red dog crouches in the snow endseq'],
#  '2269961438_cae7a9c725': ['startseq black dog is pawing dog toy endseq',
#   'startseq dog wearing coat plays with toy on fake grass endseq',
#   'startseq dog wearing jacket pounces toy endseq',
#   'startseq brown dog pounces on toy endseq',
#   'startseq grey dog wearing coat jumping to get toy endseq'],
#  '2135360514_7dcb9ed796': ['startseq baby in santa hat holds santa figure while laying on brown sofa endseq',
#   'startseq baby wearing santa hat and red outfit playing with santa claus figure endseq',
#   'startseq baby wears santa hat endseq',
#   'startseq baby in santa outfit holding baby santa endseq',
#   'startseq the baby is holding santa figurine endseq'],
#  '2780031669_a0345cfc26': ['startseq two children are in tobaggons at the top of snow covered hill endseq',
#   'startseq two children go sledding endseq',
#   'startseq two children ride saucers down snowy hill endseq',
#   'startseq two children sitting on disks in the snow endseq',
#   'startseq two children sliding in the snow endseq'],
#  '3660361818_e05367693f': ['startseq skateboarder flies through the air over the staircase of sleek contemporary building endseq',
#   'startseq skateboarder leaps of steps outside corporate building endseq',
#   'startseq people sitting on steps with large buildings in the background endseq',
#   'startseq skateboarders are doing tricks on staircase next to mirror buildings endseq',
#   'startseq someone skateboarding over steps surrounded by buildings endseq'],
#  '1229756013_94663527d7': ['startseq brown dog jumping in the air on brown plain endseq',
#   'startseq brown dog jumping into the air to catch ball endseq',
#   'startseq brown dog leaping to catch ball endseq',
#   'startseq coppery dog leaps to catch ball endseq',
#   'startseq dog leaps into the air in grassy field surrounded by trees endseq'],
#  '3247598959_5b2348444c': ['startseq brown black and white dog play in grassy field endseq',
#   'startseq white dog brown dog and black dog frolicking in grassy field endseq',
#   'startseq three dogs running on grassy field endseq',
#   'startseq three dogs run on wide grassy outdoor area endseq',
#   'startseq white brown and black dogs running across grassy lawn endseq'],
#  '3684518763_f3490b647a': ['startseq guy in gold chains black top and gold shorts is walking with his arms outstretched in parade endseq',
#   'startseq young man raises his arms as he marches in parade endseq',
#   'startseq young man with gold short shorts and black top is walking in parade endseq',
#   'startseq man in gold jewelry and shorts by parade endseq',
#   'startseq the man in the gold lame shorts is wearing many gold necklaces endseq'],
#  '3667492609_97f88b373f': ['startseq boys jumps into the water upside down endseq',
#   'startseq child diving headfirst into lake endseq',
#   'startseq man is falling backward in swim gear over large body of water nearby an urban area endseq',
#   'startseq the man is going into the water endseq',
#   'startseq the person is going into the water endseq'],
#  '241346709_23204cc2bc': ['startseq football player clutches the ball while running down the field endseq',
#   'startseq football player running with the ball endseq',
#   'startseq football player running with the ball at game endseq',
#   'startseq football player wearing gold helmet runs holding football endseq',
#   'startseq an american footballer in white strip is making run with the ball endseq'],
#  '3695517194_2a6b604cb2': ['startseq black soccer male soccer player in purple uniform with soccer ball on his head and white male soccer player in white uniform behind him endseq',
#   'startseq man in purple bumps the soccer ball with his head while man in white battles with him endseq',
#   'startseq man on the purple team heading the ball in game against the white team endseq',
#   'startseq two guys colliding while playing soccer endseq',
#   'startseq two guys playing ball and making faces endseq'],
#  '369047365_35476becc9': ['startseq couple enjoying the high plains with their dogs endseq',
#   'startseq man is taking photo of another man and his two dogs on some grassy hills endseq',
#   'startseq dog training on the mountain endseq',
#   'startseq the man wearing the white shirt takes picture of the man in the blue shirt with the two dogs endseq',
#   'startseq two men take hike with two dogs endseq'],
#  '2787276494_82703f570a': ['startseq little boy in green goggles and white life jacket jumps into the water endseq',
#   'startseq little boy in red shorts jumps into the water endseq',
#   'startseq person jumps off of ledge into body of water endseq',
#   'startseq boy with life jacket jumping into water endseq',
#   'startseq guy with ski jacket jumping off bridge into water endseq'],
#  '1814391289_83a1eb71d3': ['startseq boy dressed as spiderman ringing door bell endseq',
#   'startseq child dressed as spiderman ringing doorbell endseq',
#   'startseq child that is dressed as spiderman is ringing the doorbell endseq',
#   'startseq at halloween this little spiderman waits to get some candy endseq',
#   'startseq young child in costume rings the door bell of gray house endseq'],
#  '1956944011_c5661d3f22': ['startseq child wearing white shirt hangs from the playground equipment endseq',
#   'startseq the child in white is on the monkey bars while the one in brown stands below endseq',
#   'startseq two children are playing on monkey bars endseq',
#   'startseq two children playing on jungle gym endseq',
#   'startseq two children playing on an orange jungle gym in the winter time endseq'],
#  '3473534758_1ae3847781': ['startseq there are two boston terriers biting at each other endseq',
#   'startseq two boxers playfully snap at each other endseq',
#   'startseq two dogs are playing together with their mouths open endseq',
#   'startseq two large dogs are fighting in dirt field endseq',
#   'startseq two small dogs growling at each other in dirtbed endseq'],
#  '3578477508_b7d839da16': ['startseq boy wearing skates sliding down concrete railing of steps near pole endseq',
#   'startseq man is rollerblading down wall beside some steps endseq',
#   'startseq man is rollerskating down the wall next to some white steps endseq',
#   'startseq man on rollerblades grinding down concrete handrail endseq',
#   'startseq young man navigates sloped wall with inline skates endseq'],
#  '3442622076_c3abe955e5': ['startseq guy with glasses and beard in suit is surrounded by photographers endseq',
#   'startseq man in sports jacket with longish brown hair and glasses is getting the attention of several photographers endseq',
#   'startseq man in suit is surrounded by photographers endseq',
#   'startseq man in glasses speaks as men holding cameras look at him endseq',
#   'startseq the man surrounded by photographers is wearing gray suit and glasses endseq'],
#  '299178969_5ca1de8e40': ['startseq boy in blue in trees endseq',
#   'startseq child in jean jacket smiles while playing in tree endseq',
#   'startseq young boy with blonde hair smiling while posing on tree branch endseq',
#   'startseq blond smiling boy in denim coat sitting in tree endseq',
#   'startseq little boy climbing tree and smiling endseq'],
#  '3111502208_71e2a414f5': ['startseq blue uniformed rollerskater is struggling for the lead against longhaired tattooed and red uniformed rollerskater endseq',
#   'startseq two girls are battling it out in roller derby race with other competitors and the referee behind them endseq',
#   'startseq two women in roller derby bash into each other endseq',
#   'startseq two women on rollerskates are grappling endseq',
#   'startseq two women pushing each other during rollerskating competition endseq'],
#  '2333816000_7105d0ffac': ['startseq man climbing rock face endseq',
#   'startseq man climbs up rock endseq',
#   'startseq man wearing blue helmet is rock climbing endseq',
#   'startseq rock climber scaling stone wall endseq',
#   'startseq the man climbing the rock is wearing blue helmet endseq'],
#  '3225296260_2ee72b4917': ['startseq two people in an orange race car endseq',
#   'startseq two people in helmets sitting in an orange car endseq',
#   'startseq two people ride in orange race car endseq',
#   'startseq two people wearing helmets are sitting in race car endseq',
#   'startseq two racers driving an orange car endseq'],
#  '3081734118_6f2090215c': ['startseq brown and white dog has is mouth open ready to catch green ball endseq',
#   'startseq brown and white dog on road with its mouth open near tennis ball endseq',
#   'startseq small dog catches green tennis ball in its mouth endseq',
#   'startseq yellow and white dog is catching tennis ball on street endseq',
#   'startseq gold and white dog catching tennis ball in its mouth endseq'],
#  '1206506157_c7956accd5': ['startseq dogs fight in grass over toy endseq',
#   'startseq on grass two brown dogs tussle for orange toy endseq',
#   'startseq two dogs are playing rough in green field of grass endseq',
#   'startseq two dogs play with an orange toy in tall grass endseq',
#   'startseq two large brown dogs are playing in the grass endseq'],
#  '239807547_4923efc821': ['startseq two dogs fight next to rocks endseq',
#   'startseq two dogs playfully wrestle in rocky setting endseq',
#   'startseq two dogs playing next to rocks endseq',
#   'startseq two dogs play on the dry ground endseq',
#   'startseq two dogs sit in the shade and lick each other face endseq'],
#  '3122938209_2b2c6c1fab': ['startseq bicyclist does tricks on lime green bike endseq',
#   'startseq man dressed in black rides green bike endseq',
#   'startseq man performs stoppie trick on his bmx green bicycle with no hands endseq',
#   'startseq man on green bicycle performing trick on one wheel endseq',
#   'startseq the man is doing trick on his green bike endseq'],
#  '2419186511_f0ce5f9685': ['startseq baby is taking bath in bowl full of water endseq',
#   'startseq baby who is sticking out its tongue is being held inside bowl of water endseq',
#   'startseq cute baby takes bath in large clear bowl endseq',
#   'startseq little baby is taking bath in large tupperware bowl filled with water endseq',
#   'startseq smiling baby is sitting in large plastic tub of water endseq'],
#  '3361411074_83f27d2a1c': ['startseq brown and white dog is running up grassy hill endseq',
#   'startseq dog is running up grassy hill endseq',
#   'startseq dog on grassy hill endseq',
#   'startseq dog running uphill endseq',
#   'startseq white and brown dog is running up grassy hill endseq'],
#  '3542341321_faa2d2d48a': ['startseq two black dogs are facing each other showing their teeth endseq',
#   'startseq two brown and black dogs growling at each other endseq',
#   'startseq two brown dogs barking at each other endseq',
#   'startseq two dogs bare their teeth and bark endseq',
#   'startseq two dogs on the grass barking at each other endseq'],
#  '3271468462_701eb88d3b': ['startseq brown dog begins to bit the leg of farm animal in the grass endseq',
#   'startseq brown dog biting horse ankle endseq',
#   'startseq brown dog biting horse leg endseq',
#   'startseq cattle dog nips the leg of an animal endseq',
#   'startseq dog nips at the leg of horse endseq'],
#  '2809793070_1a3387cd6e': ['startseq three black dogs are on beach endseq',
#   'startseq three black dogs playing on the beach endseq',
#   'startseq three black dogs play on sand outside endseq',
#   'startseq three dogs playing on beach endseq',
#   'startseq three large black dogs are playing on the shore near the ocean endseq'],
#  '1117972841_2b9261f95f': ['startseq brown dog is running in the sand endseq',
#   'startseq brown dog playing in the sand endseq',
#   'startseq brown dog plays at the beach endseq',
#   'startseq dog is standing in the sand endseq',
#   'startseq dog running fast in the sand endseq'],
#  '3442138291_3e75f4bdb8': ['startseq boy runs down concrete hill endseq',
#   'startseq little boy in black shirt and blue jeans walking down path endseq',
#   'startseq little boy enjoying day at the park endseq',
# ...
#   'startseq dog chasing geese in an open field endseq',
#   'startseq large black dog is chasing two geese in field endseq',
#   'startseq dog runs after two geese in field endseq'],
#  '150582765_bad8dec237': ['startseq girl wearing pink hoodie looks through her camera endseq',
#   'startseq woman in pink taking picture endseq',
#   'startseq woman takes picture during the day endseq',
#   'startseq young woman in pink hoodie takes picture endseq',
#   'startseq woman with red curly hair taking pictures outside endseq'],
#  '3730011219_588cdc7972': ['startseq man and young child walk along the beach shore endseq',
#   'startseq man and toddler are walking along the beach in front of the ocean endseq',
#   'startseq man at the beach holding pail standing next to child endseq',
#   'startseq man with bucket and girl in hat on the beach endseq',
#   'startseq the man is wearing black shirt holding pail and walking with child next to the water endseq'],
#  '2551632823_0cb7dd779b': ['startseq man eating an apple sitting in public endseq',
#   'startseq man sits in public place eating an apple endseq',
#   'startseq man sits on bench and eats an apple endseq',
#   'startseq man sitting on ledge eating an apple endseq',
#   'startseq the man has curly brown hair is eating an apple and wearing black shirt endseq'],
#  '3407584080_c6abf71ae3': ['startseq guy making snowboarding move on slope endseq',
#   'startseq lone snowboarder jumpy in the air on snowy mountain endseq',
#   'startseq snowboarder flies through the air above the snow endseq',
#   'startseq snowboarder in midair over snow hill endseq',
#   'startseq snowboarder performing trick endseq'],
#  '3352871762_c9e88592d3': ['startseq girl with cigarette in hand and guy with green hat wave at the camera endseq',
#   'startseq man and woman show their tatooed hearts on their wrists endseq',
#   'startseq man and woman hug endseq',
#   'startseq man in green celtics hat and woman wearing black sweater display identical tattoos on their right wrists endseq',
#   'startseq there is man and woman holding up their arms and showing their heart tattoos endseq'],
#  '2268729848_d418451226': ['startseq boy hangs onto straps on train endseq',
#   'startseq boy in white and green striped shirt and black shorts endseq',
#   'startseq young boy is playing around on tram endseq',
#   'startseq young man wearing green and white shirt hanging by two straps in subway car endseq',
#   'startseq kids riding the subway endseq'],
#  '1542033433_5453d4c466': ['startseq female in green shirt standing while traffic passes endseq',
#   'startseq woman is standing next to road where the cars on the road are blurry endseq',
#   'startseq woman stands in front of pizzeria while traffic buzzes by her endseq',
#   'startseq woman stands on an urban sidewalk holding beige handbag endseq',
#   'startseq traffic is zooming past the woman wearing yellow jersey endseq'],
#  '2089555297_95cf001fa7': ['startseq man in hat with long sleeves and long pants stands overlooking city endseq',
#   'startseq man stands on cliff overlooking city endseq',
#   'startseq man with backpack and hat is standing by high cliff where you can see for miles endseq',
#   'startseq hiker standing on top of rock overlooking town endseq',
#   'startseq the man wearing backpack and hat stands on ledge overlooking city endseq'],
#  '264141937_585320617a': ['startseq woman is holding white satchel that is full of dollar bills endseq',
#   'startseq woman poses with sunglasses shaped like dollar signs and silver suitcase labelled lucky full of bills endseq',
#   'startseq woman wearing money themed costume stands on the street endseq',
#   'startseq woman wearing suitcase full of money endseq',
#   'startseq woman wearing dollar sign glasses holding dollar bill stands with suitcase that says lucky that is overflowing with cash endseq'],
#  '2501942587_e59b91d1da': ['startseq group of people near fun house at carnival endseq',
#   'startseq group of people walk through carnival endseq',
#   'startseq people standing outside at carnival endseq',
#   'startseq people walk outside of building that has many murals painted on it endseq',
#   'startseq several people are in front of colorful painted building endseq'],
#  '3541141771_67d305c873': ['startseq one person is tumbling on the ground next to another person with his shoes off endseq',
#   'startseq two boys one is climbing roof the other is bending down looking at the ground endseq',
#   'startseq two children playing on rocks endseq',
#   'startseq two people climbing some sort of object in the distance endseq',
#   'startseq two young people at park endseq'],
#  '2102724238_3cf921d7bb': ['startseq woman in knit cap and man in peacoat sit on subway laden with bags endseq',
#   'startseq people in dark clothing sit together endseq',
#   'startseq three people sitting on bench endseq',
#   'startseq two people wearing black sit on bench and look down endseq',
#   'startseq two women are sitting with their purses in their laps endseq'],
#  '954987350_a0c608b467': ['startseq female in pink tank top drinking beer endseq',
#   'startseq woman in dark pink tank top has bag across her shoulder endseq',
#   'startseq woman in pink tank top drinking out of plastic glass endseq',
#   'startseq woman in pink tank top holds plastic beer mug endseq',
#   'startseq woman wearing pink tank top holding mug of liquid endseq'],
#  '2478929971_9eb6c074b6': ['startseq girl dancing with four boys watching endseq',
#   'startseq group of boys and girls sit and talk together under tree endseq',
#   'startseq group of teenagers stand in park endseq',
#   'startseq teenagers socializing in the shade endseq',
#   'startseq the six kids are in the shade of leafy green tree endseq'],
#  '469021173_aa31c07108': ['startseq hiker wearing an orange backpack is walking through long grass endseq',
#   'startseq man walking in brush with big orange backpack endseq',
#   'startseq man with an orange backpack in an bushy area endseq',
#   'startseq person with large backpack hiking through the tall grass endseq',
#   'startseq the hiker with black and orange backpack walks away into the wooded area endseq'],
#  '3283897411_af9d0b497d': ['startseq child in pink holds an object that appears to be on fire endseq',
#   'startseq child playing with fire endseq',
#   'startseq little girl in pink top is spinning stick that has been set on fire endseq',
#   'startseq child holding an object that is on fire endseq',
#   'startseq little girl holds flaming object at sunset endseq'],
#  '3244734844_c318c29c23': ['startseq boy wearing blue parka green pants and white shoes is leaping in ramp endseq',
#   'startseq man performs large jump endseq',
#   'startseq man wearing blue jacket jumping from one concrete wall to the other endseq',
#   'startseq person in blue jacket jumps off of tan cement wall endseq',
#   'startseq someone in blue coat and white sneakers is airborne endseq'],
#  '2792409624_2731b1072c': ['startseq black and white dog is drooling whilst walking on the grass endseq',
#   'startseq black and white dog is running through grass endseq',
#   'startseq black and white dog runs across lawn while drooling endseq',
#   'startseq the black and white dog is running on the grass endseq',
#   'startseq the black and white dog runs through the grass endseq'],
#  '2682194299_92005b26c6': ['startseq black and white dog is bounding down white steps endseq',
#   'startseq black and white dog is running down some white steps endseq',
#   'startseq small dog jumping some hurdles endseq',
#   'startseq tricolored dog is jumping over obstacles endseq',
#   'startseq dog sits on hurdles endseq'],
#  '2899374885_f3b2b1a290': ['startseq baby reaching into water fountain endseq',
#   'startseq baby sticking out his tonge while looking at spraying water fountain endseq',
#   'startseq baby trying to catch water from fountain in his mouth endseq',
#   'startseq small boy is playing at water fountain endseq',
#   'startseq toddler plays in water fountain with his mouth open and ready for drink endseq'],
#  '3493844822_c315a11275': ['startseq guy surfing endseq',
#   'startseq male surfer in the air leaving the water endseq',
#   'startseq an airborne man on surfboard endseq',
#   'startseq tanned wakeboarder is leaping high in the air endseq',
#   'startseq young man on white surfboard jumping over huge wave endseq'],
#  '181157221_e12410ef0b': ['startseq man and woman walk their dogs on leashes endseq',
#   'startseq dogs straining on leashes towards each other as owners walk apart on grass endseq',
#   'startseq the two dogs are being pulled away by their owners endseq',
#   'startseq two dogs on leashes straining toward each other while their owners walk away from each other endseq',
#   'startseq two dogs try to reach each other as their human companions pull them in opposite directions by their leashes endseq'],
#  '1160034462_16b38174fe': ['startseq elderly man in straw hat is sitting on bench endseq',
#   'startseq elderly man sits alone on park bench endseq',
#   'startseq an old man in straw hat sits on park bench endseq',
#   'startseq the old man in the brown hat is sitting on the bench endseq',
#   'startseq white haired man in gray sweater and straw hat sitting on bench under tree endseq'],
#  '3033668641_5905f73990': ['startseq man in white helmet clings to sheer rock face endseq',
#   'startseq man wearing white helmet is rock climbing endseq',
#   'startseq man with all his equipment rock climbing endseq',
#   'startseq rock climber wearing white helmet endseq',
#   'startseq bearded man rock climbing endseq'],
#  '2149982207_5345633bbf': ['startseq boy wearing black and blue life vest is on green wooden boat looking out towards the water endseq',
#   'startseq boy wearing blue life jacket is holding onto the side of green boat endseq',
#   'startseq child holds on to the side of small weathered green watercraft on the open sea endseq',
#   'startseq little boy in life vest is looking out the side of boat endseq',
#   'startseq young boy riding in green boat endseq'],
#  '3648160673_0c783236a6': ['startseq dog jumps of surfboard endseq',
#   'startseq dog splashes through the water endseq',
#   'startseq dog swims in the ocean with surfboard endseq',
#   'startseq golden retriever jumping from board on an ocean beach endseq',
#   'startseq golden retriever jumps off of blue surfboard in the water endseq'],
#  '3597715122_45878432ec': ['startseq group of people waiting in line at an ice cream stand endseq',
#   'startseq group outside of ice cream place decorated with giant cone two innertubes endseq',
#   'startseq guys gathered outside an ice cream store on sunny day endseq',
#   'startseq people outside an ice cream shop that has summer decorations for sale endseq',
#   'startseq people standing outside of an ice cream stand endseq'],
#  '3618932839_acd7d2c2ea': ['startseq black and white dog jumping over hurdle endseq',
#   'startseq dog jumps over hurdle while person runs beside it endseq',
#   'startseq dog leaps over hurdle followed by its trainer endseq',
#   'startseq woman in blue running next to black and white dog as it jumps over an obstacle endseq',
#   'startseq the dog attempts to leap over the post endseq'],
#  '3122773470_b622205948': ['startseq group of people are backpacking through grassy field endseq',
#   'startseq group of people walk in line through field next to forest endseq',
#   'startseq group of people walking through grassy field endseq',
#   'startseq people on nature walk with nets and backpacks with trees to the left of them endseq',
#   'startseq several people in line walking through grass with nets in hand endseq'],
#  '1298866571_b4c496b71c': ['startseq asian man gives an evil eye to the camera endseq',
#   'startseq man in suit holds his cellphone in the air endseq',
#   'startseq serious looking young man with suit holds cellphone endseq',
#   'startseq young asian man is looking at his cellphone endseq',
#   'startseq man in suit is using his cellphone while sitting on train endseq'],
#  '1573017288_4d481856e2': ['startseq girl with arms raised in sliding down red and white slide endseq',
#   'startseq girl with extended arms goes down slide endseq',
#   'startseq girl with her arms raised riding down an inflatable slide endseq',
#   'startseq young girl with heart tank top raises her hands as she slides endseq',
#   'startseq blond child throws up her arms as she travels down slide endseq'],
#  '3381038951_225bb163af': ['startseq person is pointing at geyser endseq',
#   'startseq woman in white tshirt points at geyser endseq',
#   'startseq woman pointing at geyser endseq',
#   'startseq the girl is pointing at geyser endseq',
#   'startseq women pointing at geyser endseq'],
#  '2075041394_0b3ea1822d': ['startseq brown dog chasseing white dog endseq',
#   'startseq tan dog chases white dog through the leafy grass endseq',
#   'startseq white dog is walking through the leafy grass while brown dog is about to bite it endseq',
#   'startseq one white dog and one brown dog playing with stick endseq',
#   'startseq two little dogs run through the leaves endseq'],
#  '1330645772_24f831ff8f': ['startseq black and white dog is running in the grass endseq',
#   'startseq black dog is running across low cut field nearby an area of trees endseq',
#   'startseq black dog runs through field endseq',
#   'startseq dog runs in field endseq',
#   'startseq large black and white dog is running through grassy field endseq'],
#  '652542470_60e858da64': ['startseq girl prepares herself for the swim meet endseq',
#   'startseq young girl wearing bathing suit and goggles sits and waits endseq',
#   'startseq young swimmer sits in bathing suit and waits for the next race endseq',
#   'startseq kid sits wearing swim gear endseq',
#   'startseq young girl in competitive swimming outfit endseq'],
#  '2380740486_8cd5d4601a': ['startseq girl and some ducks walk towards the water endseq',
#   'startseq little girl is creeping behind two ducks at the top of cliff overlooking the ocean endseq',
#   'startseq person trails behind some ducks on the water to lake endseq',
#   'startseq woman walks after two geese near the ocean endseq',
#   'startseq girl with two ducks on cliff overlooking the water endseq'],
#  '608257195_6ec6f48e37': ['startseq boy dressed in an orange shirt and helmet is riding dirt bike in the woods endseq',
#   'startseq boy wearing helmet on bicycle in wooded area endseq',
#   'startseq boy with helmet mountain bikes through the woods endseq',
#   'startseq child is posing on his mountain bike and wearing helmet endseq',
#   'startseq helmeted boy bicyclist on path in the woods endseq'],
#  '221973402_ecb1cd51f1': ['startseq black dog chases boy wearing red and blue endseq',
#   'startseq boy plays with dog and frisbee endseq',
#   'startseq dog with frisbee in its mouth chasing boy in field endseq',
#   'startseq red shirted boy and black dog with frisbee run in the green grass endseq',
#   'startseq the small boy is running in front of black dog with frisbee in its mouth endseq'],
#  '2545363449_1985903f82': ['startseq girl in yellow dress is standing on the pavement outside store endseq',
#   'startseq girl in yellow dress looks at restaurant building endseq',
#   'startseq girl in yellow dress near restaurant endseq',
#   'startseq little girl in yellow dress is standing in front of restaurant endseq',
#   'startseq young girl wearing yellow dress gray pants and flip flops is standing in front of restaurant endseq'],
#  '3670075789_92ea9a183a': ['startseq child is sliding into small pool endseq',
#   'startseq girl in child swimming pool endseq',
#   'startseq little girl is sliding down short slide into an inflatable paddling pool endseq',
#   'startseq girl splashing in kiddie pool endseq',
#   'startseq the darkhaired girl is sliding into white kiddie pool endseq'],
#  '3528251308_481a28283a': ['startseq man riding skateboard jumps up on wood ledge endseq',
#   'startseq skateboarder doing moves on bench endseq',
#   'startseq skateboarder is doing trick on wooden step beside white building endseq',
#   'startseq skateboarder does manuals on bench endseq',
#   'startseq skateboarder sliding along the edge of wooden bench endseq'],
#  ...}

# %%
# convert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
    all_desc = list()
    for key in descriptions.keys():
        [all_desc.append(d) for d in descriptions[key]]
    return all_desc

# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
    lines = to_lines(descriptions)
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(lines)
    return tokenizer

# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 7579

# %%
#tokenizer.word_index

# %%
# create sequences of images, input sequences and output words for an image
def create_sequences(tokenizer, max_length, descriptions, photos):
    X1, X2, y = list(), list(), list()
    # walk through each image identifier
    for key, desc_list in descriptions.items():
        # walk through each description for the image
        for desc in desc_list:
            # encode the sequence
            seq = tokenizer.texts_to_sequences([desc])[0]
            # split one sequence into multiple X,y pairs
            for i in range(1, len(seq)):
                # split into input and output pair
                in_seq, out_seq = seq[:i], seq[i]
                # pad input sequence
                in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                # encode output sequence
                out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                # store
                X1.append(photos[key][0])
                X2.append(in_seq)
                y.append(out_seq)
    return array(X1), array(X2), array(y)

# %%
# calculate the length of the description with the most words
def max_length(descriptions):
    lines = to_lines(descriptions)
    return max(len(d.split()) for d in lines)

# %%
# define the captioning model
def define_model(vocab_size, max_length):
    # feature extractor model
    inputs1 = Input(shape=(4096,))
    fe1 = Dropout(0.5)(inputs1)
    fe2 = Dense(256, activation='relu')(fe1)
    # sequence model
    inputs2 = Input(shape=(max_length,))
    se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
    se2 = Dropout(0.5)(se1)
    se3 = LSTM(256)(se2)
    # decoder model
    decoder1 = add([fe2, se3])
    decoder2 = Dense(256, activation='relu')(decoder1)
    outputs = Dense(vocab_size, activation='softmax')(decoder2)
    # tie it together [image, seq] [word]
    model = Model(inputs=[inputs1, inputs2], outputs=outputs)
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    # summarize model
    print(model.summary())
    plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %%
# define checkpoint callback
filepath = 'model-ep{epoch:03d}-loss{loss:.3f}-val_loss{val_loss:.3f}.h5'
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %%
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)
# prepare sequences
X1train, X2train, ytrain = create_sequences(tokenizer, max_length, train_descriptions, train_features)
# Out:
# Vocabulary Size: 7579
# Description Length: 34

# %%
from numpy import array
from pickle import load
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding
from keras.layers import Dropout
from keras.layers.merge import add
from keras.callbacks import ModelCheckpoint

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load a pre-defined list of photo identifiers
def load_set(filename):
	doc = load_doc(filename)
	dataset = list()
	# process line by line
	for line in doc.split('\n'):
		# skip empty lines
		if len(line) < 1:
			continue
		# get the image identifier
		identifier = line.split('.')[0]
		dataset.append(identifier)
	return set(dataset)

# load clean descriptions into memory
def load_clean_descriptions(filename, dataset):
	# load document
	doc = load_doc(filename)
	descriptions = dict()
	for line in doc.split('\n'):
		# split line by white space
		tokens = line.split()
		# split id from description
		image_id, image_desc = tokens[0], tokens[1:]
		# skip images not in the set
		if image_id in dataset:
			# create list
			if image_id not in descriptions:
				descriptions[image_id] = list()
			# wrap description in tokens
			desc = 'startseq ' + ' '.join(image_desc) + ' endseq'
			# store
			descriptions[image_id].append(desc)
	return descriptions

# load photo features
def load_photo_features(filename, dataset):
	# load all features
	all_features = load(open(filename, 'rb'))
	# filter features
	features = {k: all_features[k] for k in dataset}
	return features

# covert a dictionary of clean descriptions to a list of descriptions
def to_lines(descriptions):
	all_desc = list()
	for key in descriptions.keys():
		[all_desc.append(d) for d in descriptions[key]]
	return all_desc

# fit a tokenizer given caption descriptions
def create_tokenizer(descriptions):
	lines = to_lines(descriptions)
	tokenizer = Tokenizer()
	tokenizer.fit_on_texts(lines)
	return tokenizer

# calculate the length of the description with the most words
def max_length(descriptions):
	lines = to_lines(descriptions)
	return max(len(d.split()) for d in lines)

# create sequences of images, input sequences and output words for an image
def create_sequences(tokenizer, max_length, desc_list, photo):
	X1, X2, y = list(), list(), list()
	# walk through each description for the image
	for desc in desc_list:
		# encode the sequence
		seq = tokenizer.texts_to_sequences([desc])[0]
		# split one sequence into multiple X,y pairs
		for i in range(1, len(seq)):
			# split into input and output pair
			in_seq, out_seq = seq[:i], seq[i]
			# pad input sequence
			in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
			# encode output sequence
			out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
			# store
			X1.append(photo)
			X2.append(in_seq)
			y.append(out_seq)
	return array(X1), array(X2), array(y)

# define the captioning model
def define_model(vocab_size, max_length):
	# feature extractor model
	inputs1 = Input(shape=(4096,))
	fe1 = Dropout(0.5)(inputs1)
	fe2 = Dense(256, activation='relu')(fe1)
	# sequence model
	inputs2 = Input(shape=(max_length,))
	se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
	se2 = Dropout(0.5)(se1)
	se3 = LSTM(256)(se2)
	# decoder model
	decoder1 = add([fe2, se3])
	decoder2 = Dense(256, activation='relu')(decoder1)
	outputs = Dense(vocab_size, activation='softmax')(decoder2)
	# tie it together [image, seq] [word]
	model = Model(inputs=[inputs1, inputs2], outputs=outputs)
	# compile model
	model.compile(loss='categorical_crossentropy', optimizer='adam')
	# summarize model
	model.summary()
	plot_model(model, to_file='model.png', show_shapes=True)
	return model

# data generator, intended to be used in a call to model.fit_generator()
def data_generator(descriptions, photos, tokenizer, max_length):
	# loop for ever over images
	while 1:
		for key, desc_list in descriptions.items():
			# retrieve the photo feature
			photo = photos[key][0]
			in_img, in_seq, out_word = create_sequences(tokenizer, max_length, desc_list, photo)
			yield [[in_img, in_seq], out_word]

# load training dataset (6K)
filename = 'Flickr_8k.trainImages.txt'
train = load_set(filename)
print('Dataset: %d' % len(train))
# descriptions
train_descriptions = load_clean_descriptions('descriptions.txt', train)
print('Descriptions: train=%d' % len(train_descriptions))
# photo features
train_features = load_photo_features('features.pkl', train)
print('Photos: train=%d' % len(train_features))
# prepare tokenizer
tokenizer = create_tokenizer(train_descriptions)
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# determine the maximum sequence length
max_length = max_length(train_descriptions)
print('Description Length: %d' % max_length)

# define the model
model = define_model(vocab_size, max_length)
# train the model, run epochs manually and save after each epoch
epochs = 20
steps = len(train_descriptions)
for i in range(epochs):
	# create the data generator
	generator = data_generator(train_descriptions, train_features, tokenizer, max_length)
	# fit for one epoch
	model.fit_generator(generator, epochs=1, steps_per_epoch=steps, verbose=1)
	# save model
	model.save('model_' + str(i) + '.h5')
# Out:
# Dataset: 6000
# Descriptions: train=6000
# Photos: train=6000
# Vocabulary Size: 7579
# Description Length: 34
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_6 (InputLayer)            (None, 34)           0
# __________________________________________________________________________________________________
# input_5 (InputLayer)            (None, 4096)         0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 34, 256)      1940224     input_6[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 4096)         0           input_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 34, 256)      0           embedding_3[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 256)          1048832     dropout_5[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   (None, 256)          525312      dropout_6[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 256)          0           dense_7[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 256)          65792       add_3[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 7579)         1947803     dense_8[0][0]
# ==================================================================================================
# Total params: 5,527,963
# Trainable params: 5,527,963
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/keras/utils/vis_utils.py in _check_pydot()
#      26         # to check the pydot/graphviz installation.
# ---> 27         pydot.Dot.create(pydot.Dot())
#      28     except Exception:
#
# AttributeError: 'NoneType' object has no attribute 'Dot'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-1867909ca6c8> in <module>()
#     160
#     161 # define the model
# --> 162 model = define_model(vocab_size, max_length)
#     163 # train the model, run epochs manually and save after each epoch
#     164 epochs = 20
#
# <ipython-input-6-1867909ca6c8> in define_model(vocab_size, max_length)
#     128         # summarize model
#     129         model.summary()
# --> 130         plot_model(model, to_file='model.png', show_shapes=True)
#     131         return model
#     132
#
# /usr/local/lib/python3.5/dist-packages/keras/utils/vis_utils.py in plot_model(model, to_file, show_shapes, show_layer_names, rankdir)
#     133             'LR' creates a horizontal plot.
#     134     """
# --> 135     dot = model_to_dot(model, show_shapes, show_layer_names, rankdir)
#     136     _, extension = os.path.splitext(to_file)
#     137     if not extension:
#
# /usr/local/lib/python3.5/dist-packages/keras/utils/vis_utils.py in model_to_dot(model, show_shapes, show_layer_names, rankdir)
#      54     from ..models import Sequential
#      55
# ---> 56     _check_pydot()
#      57     dot = pydot.Dot()
#      58     dot.set('rankdir', rankdir)
#
# /usr/local/lib/python3.5/dist-packages/keras/utils/vis_utils.py in _check_pydot()
#      29         # pydot raises a generic Exception here,
#      30         # so no specific class can be caught.
# ---> 31         raise ImportError('Failed to import pydot. You must install pydot'
#      32                           ' and graphviz for `pydotprint` to work.')
#      33
#
# ImportError: Failed to import pydot. You must install pydot and graphviz for `pydotprint` to work.
